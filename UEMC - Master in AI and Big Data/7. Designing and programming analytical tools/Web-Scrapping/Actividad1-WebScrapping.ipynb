# %%
import requests
import re
url = 'https://www.uemc.es'
r = requests.get(url)
print (re.search('<\W*title\W*(.*)</title>', r.text,\
re.IGNORECASE).group(1))
# Out:
# Universidad Europea Miguel de Cervantes

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://en.wikipedia.org/w/index.php' + \
'?title=List_of_Game_of_Thrones_episodes&oldid=802553687'
r = requests.get(url)
html_contents = r.text
html_soup = BeautifulSoup(html_contents, 'html.parser')

# %%
# !pip3 install selenium
# Out:
# ...
#      |████████████████████████████████| 968 kB 4.9 MB/s
# ...
#      |████████████████████████████████| 359 kB 19.1 MB/s
# ...
#      |████████████████████████████████| 138 kB 53.9 MB/s
# ...
#      |████████████████████████████████| 3.6 MB 42.9 MB/s
# ...
#      |████████████████████████████████| 55 kB 3.4 MB/s
# ...
#      |████████████████████████████████| 58 kB 4.4 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.9 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
from selenium import webdriver
from selenium.webdriber.chrome.options import Options
options = Options()
options.headless = True
driver = webdriver.Chrome(options=options, executable_path=DRIVER_PATH)
driver.get("http://www.google.es")
print(driver.page_source)
diver.quit()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-15f683eb2c98> in <module>()
#       1 from selenium import webdriver
# ----> 2 from selenium.webdriber.chrome.options import Options
#       3 options = Options()
#       4 options.headless = True
#       5 driver = webdriver.Chrome(options=options, executable_path=DRIVER_PATH)
#
# ModuleNotFoundError: No module named 'selenium.webdriber'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# https://medium.com/@nutanbhogendrasharma/extract-table-data-from-wikipedia-using-web-scraping-with-python-d13505ecdc9c

# %%
# !python -m pip install requests

# %%
import requests
r = requests.get('https://es.wikipedia.org/wiki/Anexo:Erupciones_volc%C3%A1nicas_m%C3%A1s_grandes')

# %%
page_url = 'https://es.wikipedia.org/wiki/Anexo:Erupciones_volc%C3%A1nicas_m%C3%A1s_grandes'
html = requests.get(page_url, timeout = 5, verify = True)
print(html)
# Out:
# <Response [200]>

# %%
html.text[:1000]
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="es" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Anexo:Erupciones volcánicas más grandes - Wikipedia, la enciclopedia libre</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":[",\\t.","\xa0\\t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","enero","febrero","marzo","abril","mayo","junio","julio","agosto","septiembre","octubre","noviembre","diciembre"],"wgRequestId":"a4d77377-03b4-4b19-89c8-6c8607102687","wgCSPNonce":false,"wgCanonicalNamespace":"Anexo","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":104,"wgPageName":"Anexo:Erupciones_volcánicas_más_grandes","wgTitle":"Erupciones volcánicas más grandes","wgCurRevisionId":140890904,"wgRevisionId":140890904,"wgArticleId":4765705,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia:Páginas con referen
# ...

# %%
dfs = pd.read_html(html.text)
dfs
# Out:
# [                                  Volcán—Erupción[7]​ Antigüedad (Ma)[n 2]​  \
#  0                        Guarapuava —Tamarana—Sarusas                   132
#  1                                    Santa Maria—Fria                  ~132
#  2                                 Guarapuava —Ventura                  ~132
#  3                   Ignimbrita de Sam y toba de Green                   295
#  4   Centro volcánico de Goboboseb–Messum unidad de...                   132
#  5                             Caxias do Sul—Grootberg                  ~132
#  6            Caldera de La Garita—Toba de Fish Canyon                   278
#  7                                  Jacui—Goboboseb II                  ~132
#  8                                   Ourinhos—Khoraseb                  ~132
#  9                            Ignimbrita de Jabal Kura                   296
#  10                              Toba de Windows Butte                   314
# ...

# %%
len(dfs)
# Out:
# 1

# %%
df = dfs[0]
df.head()
# Out:
#                                  Volcán—Erupción[7]​ Antigüedad (Ma)[n 2]​  \
# 0                       Guarapuava —Tamarana—Sarusas                   132
# 1                                   Santa Maria—Fria                  ~132
# 2                                Guarapuava —Ventura                  ~132
# 3                  Ignimbrita de Sam y toba de Green                   295
# 4  Centro volcánico de Goboboseb–Messum unidad de...                   132
#
#                                           Sitio Volumen (km³)[n 3]​  \
# 0                    Traps de Paraná y Etendeka                8600
# 1                    Traps de Paraná y Etendeka                7800
# 2                    Traps de Paraná y Etendeka                7600
# 3                                         Yemen                6800
# 4  Traps de Paraná y Etendeka, Brasil y Namibia                6340
#
#                                                Notas  Refs
# ...

# %%
df.shape
# Out:
# (40, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Volcán—Erupción[7]​    40 non-null     object
#  1   Antigüedad (Ma)[n 2]​  40 non-null     object
#  2   Sitio                  40 non-null     object
#  3   Volumen (km³)[n 3]​    40 non-null     object
#  4   Notas                  28 non-null     object
#  5   Refs                   40 non-null     object
# dtypes: object(6)
# memory usage: 2.0+ KB

# %%
#print(df.columns.tolist())
print(df.columns)
# Out:
# Index(['Volcán—Erupción[7]​', 'Antigüedad (Ma)[n 2]​', 'Sitio',
#        'Volumen (km³)[n 3]​', 'Notas', 'Refs'],
#       dtype='object')

# %%
df = df.rename(columns ={'Volcán—Erupción[7]': 'Volcán—Erupción', 'Antigüedad (Ma)[n 2]': 'Antiguedad​', 'Volumen (km³)[n 3]': 'Volumen'})
df.columns
# Out:
# Index(['Volcán—Erupción[7]​', 'Antigüedad (Ma)[n 2]​', 'Sitio',
#        'Volumen (km³)[n 3]​', 'Notas', 'Refs'],
#       dtype='object')

# %% [markdown]
# #### Ordenar el data frame por orden de Antigüedad

# %%
#pd.to_numeric(df['Antigüedad (Ma)[n 2]'], errors = 'coerce')
df.sort_values(by=['Antigüedad (Ma)[n 2]'], ascending=False)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-74cd0571adb9> in <module>()
#       1 #pd.to_numeric(df['Antigüedad (Ma)[n 2]'], errors = 'coerce')
# ----> 2 df.sort_values(by=['Antigüedad (Ma)[n 2]'], ascending=False)
#       3 df
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6257
#    6258             by = by[0]
# -> 6259             k = self._get_label_or_level_values(by, axis=axis)
#    6260
#    6261             # need to rewrap column in Series to apply key function
#
# ...
